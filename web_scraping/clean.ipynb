# %%
from covid19_healthdata_scraper import covid19_healthdata_scrape, covid19_healthdate_bystate
from states import us_states_list as us_states

# %%
for state in us_states:
    covid19_healthdata_scrape(state)

# %%
covid19_healthdate_bystate
# Out:
# [{'state': 'alabama',
#   'state_data': {'Mass Gathering Restriction': 'March 19, 2020',
#    'Initual Business Closure': 'March 19, 2020',
#    'Educational Facilities Closure': 'March 19, 2020',
#    'Non-Essential Services Closure': 'March 28, 2020',
#    'Stay at Home Order': 'April 4, 2020'}},
#  {'state': 'alaska',
#   'state_data': {'Mass Gathering Restriction': 'March 24, 2020',
#    'Initual Business Closure': 'March 17, 2020',
#    'Educational Facilities Closure': 'March 16, 2020',
#    'Non-Essential Services Closure': 'March 28, 2020',
#    'Stay at Home Order': 'March 28, 2020'}},
#  {'state': 'arizona',
#   'state_data': {'Mass Gathering Restriction': 'March 30, 2020',
#    'Initual Business Closure': 'Not implemented',
#    'Educational Facilities Closure': 'March 16, 2020',
#    'Non-Essential Services Closure': 'Not implemented',
#    'Stay at Home Order': 'March 30, 2020'}},
#  {'state': 'arkansas',
# ...
